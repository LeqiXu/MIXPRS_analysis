# %% [markdown]
# ## Estimate PRS Score for AFR and AMR

# %%
import os

bucket = os.getenv('WORKSPACE_BUCKET')

# !gsutil cp -r {bucket}/JointPRS/data/ ./
# !gsutil cp -r {bucket}/JointPRS/result/ ./
# Out:
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/cov_data/ancestry.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/cov_data/ancestry_pc.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/BMI_BridgePRS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/DBP_BridgePRS_EUR_AFR_beta_AFR.txt...
# / [4 files][186.5 MiB/186.5 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/HDL_BridgePRS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/HDL_BridgePRS_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/Height_BridgePRS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/LDL_BridgePRS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/LDL_BridgePRS_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/PLT_BridgePRS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/SBP_BridgePRS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/TC_BridgePRS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/TC_BridgePRS_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/logTG_BridgePRS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/BridgePRS/logTG_BridgePRS_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/BMI_JointPRS_linear_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/BMI_JointPRS_linear_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/BMI_JointPRS_linear_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/BMI_JointPRS_meta_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/BMI_JointPRS_meta_EUR_EAS_AFR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/BMI_JointPRS_meta_EUR_EAS_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/BMI_JointPRS_meta_EUR_EAS_AFR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/BMI_JointPRS_meta_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/DBP_JointPRS_linear_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/DBP_JointPRS_linear_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/DBP_JointPRS_linear_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/DBP_JointPRS_meta_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/DBP_JointPRS_meta_EUR_EAS_AFR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/DBP_JointPRS_meta_EUR_EAS_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/DBP_JointPRS_meta_EUR_EAS_AFR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/DBP_JointPRS_meta_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_r2_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_weight_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_SAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_pvalue_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_r2_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/Height_JointPRS_linear_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/Height_JointPRS_linear_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/Height_JointPRS_linear_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/Height_JointPRS_meta_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/Height_JointPRS_meta_EUR_EAS_AFR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/Height_JointPRS_meta_EUR_EAS_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/Height_JointPRS_meta_EUR_EAS_AFR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/Height_JointPRS_meta_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_r2_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_weight_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_SAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_pvalue_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/LDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_r2_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/PLT_JointPRS_linear_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/PLT_JointPRS_linear_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/PLT_JointPRS_linear_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/PLT_JointPRS_meta_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/PLT_JointPRS_meta_EUR_EAS_AFR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/PLT_JointPRS_meta_EUR_EAS_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/PLT_JointPRS_meta_EUR_EAS_AFR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/PLT_JointPRS_meta_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/SBP_JointPRS_linear_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/SBP_JointPRS_linear_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/SBP_JointPRS_linear_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/SBP_JointPRS_meta_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/SBP_JointPRS_meta_EUR_EAS_AFR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/SBP_JointPRS_meta_EUR_EAS_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/SBP_JointPRS_meta_EUR_EAS_AFR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/SBP_JointPRS_meta_EUR_EAS_AFR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_r2_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_weight_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_SAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_pvalue_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/TC_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_r2_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_r2_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_weight_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_beta_SAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_pvalue_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_pvalue_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_r2_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/JointPRS/logTG_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_r2_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/BMI_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/DBP_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/GLGC_MIX_final_NNLS_weights.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/GLGC_simple_linear_weights.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/HDL_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/HDL_AMR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/Height_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/LDL_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/LDL_AMR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/PAGE_MIX_final_NNLS_weights.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/PAGE_simple_linear_weights.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/PLT_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/SBP_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/TC_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/TC_AMR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/logTG_AFR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MIXPRS/logTG_AMR_MIXPRS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/BMI_MUSSEL_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/DBP_MUSSEL_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/HDL_MUSSEL_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/HDL_MUSSEL_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/Height_MUSSEL_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/LDL_MUSSEL_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/LDL_MUSSEL_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/PLT_MUSSEL_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/SBP_MUSSEL_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/TC_MUSSEL_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/TC_MUSSEL_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/logTG_MUSSEL_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/MUSSEL/logTG_MUSSEL_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/BMI_PROSPER_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/BMI_PROSPER_update_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/DBP_PROSPER_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/DBP_PROSPER_update_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/HDL_PROSPER_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/HDL_PROSPER_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/HDL_PROSPER_update_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/HDL_PROSPER_update_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/Height_PROSPER_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/Height_PROSPER_update_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/LDL_PROSPER_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/LDL_PROSPER_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/LDL_PROSPER_update_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/LDL_PROSPER_update_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/PLT_PROSPER_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/PLT_PROSPER_update_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/SBP_PROSPER_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/SBP_PROSPER_update_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/TC_PROSPER_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/TC_PROSPER_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/TC_PROSPER_update_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/TC_PROSPER_update_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/logTG_PROSPER_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/logTG_PROSPER_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/logTG_PROSPER_update_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PROSPER/logTG_PROSPER_update_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/BMI_PRScsx_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/BMI_PRScsx_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/DBP_PRScsx_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/DBP_PRScsx_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/HDL_PRScsx_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/HDL_PRScsx_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/HDL_PRScsx_EUR_EAS_AFR_SAS_AMR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/HDL_PRScsx_EUR_EAS_AFR_SAS_AMR_weight_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/Height_PRScsx_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/Height_PRScsx_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/LDL_PRScsx_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/LDL_PRScsx_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/LDL_PRScsx_EUR_EAS_AFR_SAS_AMR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/LDL_PRScsx_EUR_EAS_AFR_SAS_AMR_weight_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/PLT_PRScsx_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/PLT_PRScsx_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/SBP_PRScsx_EUR_EAS_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/SBP_PRScsx_EUR_EAS_AFR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/TC_PRScsx_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/TC_PRScsx_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/TC_PRScsx_EUR_EAS_AFR_SAS_AMR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/TC_PRScsx_EUR_EAS_AFR_SAS_AMR_weight_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/logTG_PRScsx_EUR_EAS_AFR_SAS_AMR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/logTG_PRScsx_EUR_EAS_AFR_SAS_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/logTG_PRScsx_EUR_EAS_AFR_SAS_AMR_weight_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/PRScsx/logTG_PRScsx_EUR_EAS_AFR_SAS_AMR_weight_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/BMI_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/BMI_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/BMI_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/DBP_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/DBP_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/DBP_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/HDL_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/HDL_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/HDL_SDPRX_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/HDL_SDPRX_EUR_AMR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/HDL_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/HDL_SDPRX_EUR_SAS_beta_SAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/Height_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/Height_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/Height_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/LDL_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/LDL_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/LDL_SDPRX_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/LDL_SDPRX_EUR_AMR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/LDL_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/LDL_SDPRX_EUR_SAS_beta_SAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/PLT_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/PLT_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/PLT_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/SBP_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/SBP_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/SBP_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/TC_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/TC_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/TC_SDPRX_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/TC_SDPRX_EUR_AMR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/TC_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/TC_SDPRX_EUR_SAS_beta_SAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/logTG_SDPRX_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/logTG_SDPRX_EUR_AFR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/logTG_SDPRX_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/logTG_SDPRX_EUR_AMR_beta_EUR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/logTG_SDPRX_EUR_EAS_beta_EAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/SDPRX/logTG_SDPRX_EUR_SAS_beta_SAS.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/BMI_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/DBP_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/HDL_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/HDL_XPASS_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/Height_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/LDL_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/LDL_XPASS_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/PLT_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/SBP_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/TC_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/TC_XPASS_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/logTG_XPASS_EUR_AFR_beta_AFR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/final_weight/diff_cohort/XPASS/logTG_XPASS_EUR_AMR_beta_AMR.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AFR.bed...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AFR.bim...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AFR.fam...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AFR.nosex...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AMR.bed...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AMR.bim...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AMR.fam...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/AMR.nosex...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/EUR.bed...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/EUR.bim...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/EUR.fam...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/mergelist.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/ukbb_data/AFR.bim...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/ukbb_data/AFR_mapping.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/ukbb_data/AFR_snplist.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/ukbb_data/AMR.bim...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/ukbb_data/AMR_mapping.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/geno_data/ukbb_data/AMR_snplist.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/BMI.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/DBP.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/HDL.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/Height.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/LDL.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/PLT.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/SBP.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/TC.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/pheno_data/logTG.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/snplist_data/AFR_inter_snplist_aou.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/snplist_data/AFR_inter_snplist_ukbb.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/snplist_data/AMR_inter_snplist_aou.txt...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/data/snplist_data/AMR_inter_snplist_ukbb.txt...
# | [282 files][ 49.5 GiB/ 49.5 GiB]   20.5 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 282 objects/49.5 GiB.
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/PRS/MIXPRS_update_diff_cohort_r2.csv...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/PRS/PRS_diff_cohort_r2.csv...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/PRS/PRS_update_diff_cohort_r2.csv...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/BMI_BridgePRS_EUR_AFR_prs_AFR.log...
# / [4 files][  5.9 KiB/  5.9 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/BMI_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/DBP_BridgePRS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/DBP_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/HDL_BridgePRS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/HDL_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/HDL_BridgePRS_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/HDL_BridgePRS_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/Height_BridgePRS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/Height_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/LDL_BridgePRS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/LDL_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/LDL_BridgePRS_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/LDL_BridgePRS_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/PLT_BridgePRS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/PLT_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/SBP_BridgePRS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/SBP_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/TC_BridgePRS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/TC_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/TC_BridgePRS_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/TC_BridgePRS_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/logTG_BridgePRS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/logTG_BridgePRS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/logTG_BridgePRS_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/BridgePRS/logTG_BridgePRS_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/BMI_JointPRS_linear_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/BMI_JointPRS_linear_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/BMI_JointPRS_meta_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/BMI_JointPRS_meta_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/DBP_JointPRS_linear_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/DBP_JointPRS_linear_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/DBP_JointPRS_meta_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/DBP_JointPRS_meta_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/HDL_JointPRS_linear_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/JointPRS/HDL_JointPRS_meta_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# ...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/LDL_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/LDL_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/LDL_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/LDL_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/LDL_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/LDL_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/LDL_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/PLT_PROSPER_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/PLT_PROSPER_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/PLT_PROSPER_update_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/PLT_PROSPER_update_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/SBP_PROSPER_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/SBP_PROSPER_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/SBP_PROSPER_update_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/SBP_PROSPER_update_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/TC_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/TC_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/TC_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/TC_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/TC_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/TC_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/TC_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/TC_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/logTG_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/logTG_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/logTG_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/logTG_PROSPER_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/logTG_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/logTG_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/logTG_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PROSPER/logTG_PROSPER_update_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/BMI_PRScsx_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/BMI_PRScsx_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/DBP_PRScsx_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/DBP_PRScsx_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/HDL_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/HDL_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/HDL_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/HDL_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/Height_PRScsx_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/Height_PRScsx_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/LDL_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/LDL_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/LDL_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/LDL_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/PLT_PRScsx_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/PLT_PRScsx_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/SBP_PRScsx_EUR_EAS_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/SBP_PRScsx_EUR_EAS_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/TC_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/TC_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/TC_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/TC_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/logTG_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/logTG_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/logTG_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/PRScsx/logTG_PRScsx_EUR_EAS_AFR_SAS_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/BMI_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/BMI_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/DBP_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/DBP_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/HDL_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/HDL_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/HDL_SDPRX_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/HDL_SDPRX_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/Height_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/Height_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/LDL_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/LDL_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/LDL_SDPRX_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/LDL_SDPRX_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/PLT_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/PLT_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/SBP_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/SBP_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/TC_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/TC_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/TC_SDPRX_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/TC_SDPRX_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/logTG_SDPRX_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/logTG_SDPRX_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/logTG_SDPRX_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/SDPRX/logTG_SDPRX_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/BMI_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/BMI_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/DBP_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/DBP_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/HDL_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/HDL_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/HDL_XPASS_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/HDL_XPASS_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/Height_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/Height_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/LDL_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/LDL_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/LDL_XPASS_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/LDL_XPASS_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/PLT_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/PLT_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/SBP_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/SBP_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/TC_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/TC_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/TC_XPASS_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/TC_XPASS_EUR_AMR_prs_AMR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/logTG_XPASS_EUR_AFR_prs_AFR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/logTG_XPASS_EUR_AFR_prs_AFR.sscore...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/logTG_XPASS_EUR_AMR_prs_AMR.log...
# Copying gs://fc-secure-0fedc240-1521-487f-b634-96a221bfbb61/JointPRS/result/score/diff_cohort/XPASS/logTG_XPASS_EUR_AMR_prs_AMR.sscore...
# / [483 files][473.5 MiB/473.5 MiB]    6.1 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 483 objects/473.5 MiB.

# %% [markdown]
# ### Estimate PRS Score for GLGC AFR and AMR

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## MIXPRS
# method=MIXPRS
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${pop2}_${method}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${pop2}_${method}.txt header-read \
#     --out ./result/score/diff_cohort/${method}/${trait}_${pop2}_${method}
# fi
#
# done
#
# done
# Out:
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/HDL_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/HDL_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/HDL_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:23:32 2025
# 26057 MiB RAM detected, ~23778 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3321 entries in
# ./data/final_weight/diff_cohort/MIXPRS/HDL_AFR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824406 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/HDL_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:24:54 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/HDL_AMR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AMR
#   --extract ./data/snplist_data/AMR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/HDL_AMR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/HDL_AMR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:24:54 2025
# 26057 MiB RAM detected, ~23762 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 40838 samples (0 females, 0 males, 40838 ambiguous; 40838 founders) loaded from
# ./data/geno_data/AMR.fam.
# 1105425 variants loaded from ./data/geno_data/AMR.bim.
# Note: No phenotype data present.
# --extract: 1105425 variants remaining.
# Calculating allele frequencies... 111723293541475359657177838894done.
# 1105425 variants remaining after main filters.
# Warning: --score: 8653 entries in
# ./data/final_weight/diff_cohort/MIXPRS/HDL_AMR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 1099270 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/HDL_AMR_MIXPRS.sscore .
# End time: Wed Sep 24 03:28:55 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/LDL_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/LDL_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/LDL_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:28:55 2025
# 26057 MiB RAM detected, ~23777 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3321 entries in
# ./data/final_weight/diff_cohort/MIXPRS/LDL_AFR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824406 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/LDL_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:33:15 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/LDL_AMR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AMR
#   --extract ./data/snplist_data/AMR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/LDL_AMR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/LDL_AMR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:33:15 2025
# 26057 MiB RAM detected, ~23777 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 40838 samples (0 females, 0 males, 40838 ambiguous; 40838 founders) loaded from
# ./data/geno_data/AMR.fam.
# 1105425 variants loaded from ./data/geno_data/AMR.bim.
# Note: No phenotype data present.
# --extract: 1105425 variants remaining.
# Calculating allele frequencies... 111723293541475359657177838894done.
# 1105425 variants remaining after main filters.
# Warning: --score: 8592 entries in
# ./data/final_weight/diff_cohort/MIXPRS/LDL_AMR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 1095925 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/LDL_AMR_MIXPRS.sscore .
# End time: Wed Sep 24 03:34:31 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/TC_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/TC_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/TC_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:34:31 2025
# 26057 MiB RAM detected, ~23774 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3321 entries in
# ./data/final_weight/diff_cohort/MIXPRS/TC_AFR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824406 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/TC_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:35:47 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/TC_AMR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AMR
#   --extract ./data/snplist_data/AMR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/TC_AMR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/TC_AMR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:35:47 2025
# 26057 MiB RAM detected, ~23761 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 40838 samples (0 females, 0 males, 40838 ambiguous; 40838 founders) loaded from
# ./data/geno_data/AMR.fam.
# 1105425 variants loaded from ./data/geno_data/AMR.bim.
# Note: No phenotype data present.
# --extract: 1105425 variants remaining.
# Calculating allele frequencies... 111723293541475359657177838894done.
# 1105425 variants remaining after main filters.
# Warning: --score: 8723 entries in
# ./data/final_weight/diff_cohort/MIXPRS/TC_AMR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 1102343 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/TC_AMR_MIXPRS.sscore .
# End time: Wed Sep 24 03:37:02 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/logTG_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/logTG_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/logTG_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:37:02 2025
# 26057 MiB RAM detected, ~23756 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3321 entries in
# ./data/final_weight/diff_cohort/MIXPRS/logTG_AFR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824406 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/logTG_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:38:17 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/logTG_AMR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AMR
#   --extract ./data/snplist_data/AMR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/logTG_AMR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/logTG_AMR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:38:17 2025
# 26057 MiB RAM detected, ~23780 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 40838 samples (0 females, 0 males, 40838 ambiguous; 40838 founders) loaded from
# ./data/geno_data/AMR.fam.
# 1105425 variants loaded from ./data/geno_data/AMR.bim.
# Note: No phenotype data present.
# --extract: 1105425 variants remaining.
# Calculating allele frequencies... 111723293541475359657177838894done.
# 1105425 variants remaining after main filters.
# Warning: --score: 8687 entries in
# ./data/final_weight/diff_cohort/MIXPRS/logTG_AMR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 1100439 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/logTG_AMR_MIXPRS.sscore .
# End time: Wed Sep 24 03:39:32 2025

# %%
# %%bash
#
# ## JointPRS
# for trait in HDL LDL TC logTG; do
# for pop2 in AFR AMR; do
#
# for pop in EUR EAS AFR SAS AMR; do
#
# method=JointPRS
#
# if [[ ! -e ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_beta_${pop}_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/JointPRS_auto/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_beta_${pop}.txt \
#     --out ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_beta_${pop}_prs_${pop2}
# fi
#
# done
# done
#
# done
#
# ## SDPRX
# for trait in HDL LDL TC logTG; do
# for pop2 in AFR AMR; do
#
# for pop in EAS AFR SAS AMR; do
#
# method=SDPRX
#
# if [[ ! -e ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_${pop}_beta_${pop}_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_${pop}_beta_${pop}.txt \
#     --out ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_${pop}_beta_${pop}_prs_${pop2}
# fi
#
# done
#
# method=SDPRX
#
# if [[ ! -e ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_${pop2}_beta_EUR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_beta_EUR.txt \
#     --out ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_${pop2}_beta_EUR_prs_${pop2}
# fi
#
# done
# done

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## JointPRS_meta
# method=JointPRS_meta
#
# if [[ ! -e ./result/score/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}
# fi
#
# done
#
# done

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## JointPRS_linear
# method=JointPRS_linear
#
# if [[ ! -e ./result/score/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_beta_${pop2}.txt header-read \
#     --score-col-nums 3 4 5 6 7 \
#     --out ./result/score/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}
# fi
#
# done
#
# done

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## XPASS
# method=XPASS
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_prs_${pop2}
# fi
#
# done
#
# done

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## PRScsx
# method=PRScsx
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_beta_${pop2}.txt header-read \
#     --score-col-nums 3 4 5 6 7 \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}
# fi
#
# done
#
# done

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## MUSSEL
# method=MUSSEL
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}
# fi
#
# done
#
# done

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## PROSPER
# method=PROSPER
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_SAS_AMR_prs_${pop2}
# fi
#
# done
#
# done

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## PROSPER
# method=PROSPER
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_update_EUR_EAS_AFR_SAS_AMR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_update_EUR_EAS_AFR_SAS_AMR_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_update_EUR_EAS_AFR_SAS_AMR_prs_${pop2}
# fi
#
# done
#
# done

# %%
# %%bash
#
# for trait in HDL LDL TC logTG; do
#
# for pop2 in AFR AMR; do
#
# ## BridgePRS
# method=BridgePRS
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_prs_${pop2}
# fi
#
# done
#
# done

# %% [markdown]
# ### Estimate PRS Score for PAGE AFR

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# for pop2 in AFR; do
#
# ## MIXPRS
# method=MIXPRS
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${pop2}_${method}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${pop2}_${method}.txt header-read \
#     --out ./result/score/diff_cohort/${method}/${trait}_${pop2}_${method}
# fi
#
# done
#
# done
# Out:
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/Height_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/Height_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/Height_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:39:32 2025
# 26057 MiB RAM detected, ~23777 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3325 entries in
# ./data/final_weight/diff_cohort/MIXPRS/Height_AFR_MIXPRS.txt were skipped due
# to missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824413 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/Height_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:40:47 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/BMI_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/BMI_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/BMI_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:40:47 2025
# 26057 MiB RAM detected, ~23780 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3325 entries in
# ./data/final_weight/diff_cohort/MIXPRS/BMI_AFR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824413 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/BMI_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:42:02 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/SBP_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/SBP_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/SBP_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:42:02 2025
# 26057 MiB RAM detected, ~23776 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3325 entries in
# ./data/final_weight/diff_cohort/MIXPRS/SBP_AFR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824413 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/SBP_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:43:16 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/DBP_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/DBP_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/DBP_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:43:17 2025
# 26057 MiB RAM detected, ~23782 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3325 entries in
# ./data/final_weight/diff_cohort/MIXPRS/DBP_AFR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824413 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/DBP_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:44:32 2025
# PLINK v2.0.0-a.6.12LM 64-bit Intel (20 Apr 2025)   cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./result/score/diff_cohort/MIXPRS/PLT_AFR_MIXPRS.log.
# Options in effect:
#   --bfile ./data/geno_data/AFR
#   --extract ./data/snplist_data/AFR_inter_snplist_aou.txt
#   --out ./result/score/diff_cohort/MIXPRS/PLT_AFR_MIXPRS
#   --score ./data/final_weight/diff_cohort/MIXPRS/PLT_AFR_MIXPRS.txt header-read
#
# Start time: Wed Sep 24 03:44:32 2025
# 26057 MiB RAM detected, ~23781 available; reserving 13028 MiB for main
# workspace.
# Using up to 4 compute threads.
# 53944 samples (0 females, 0 males, 53944 ambiguous; 53944 founders) loaded from
# ./data/geno_data/AFR.fam.
# 824452 variants loaded from ./data/geno_data/AFR.bim.
# Note: No phenotype data present.
# --extract: 824452 variants remaining.
# Calculating allele frequencies... 1523313947556371798795done.
# 824452 variants remaining after main filters.
# Warning: --score: 3325 entries in
# ./data/final_weight/diff_cohort/MIXPRS/PLT_AFR_MIXPRS.txt were skipped due to
# missing variant IDs.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# --score: 824413 variants processed.
# --score: Results written to
# ./result/score/diff_cohort/MIXPRS/PLT_AFR_MIXPRS.sscore .
# End time: Wed Sep 24 03:45:54 2025

# %%
# %%bash
#
# ## JointPRS
# for trait in Height BMI SBP DBP PLT; do
# for pop2 in AFR; do
#
# for pop in EUR EAS AFR; do
#
# method=JointPRS
#
# if [[ ! -e ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_EAS_AFR_beta_${pop}_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/JointPRS_auto/${trait}_${method}_EUR_EAS_AFR_beta_${pop}.txt \
#     --out ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_EAS_AFR_beta_${pop}_prs_${pop2}
# fi
#
# done
# done
#
# done
#
# ## SDPRX
# for trait in Height BMI SBP DBP PLT; do
# for pop2 in AFR; do
#
# for pop in EAS AFR; do
#
#
# method=SDPRX
#
# if [[ ! -e ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_${pop}_beta_${pop}_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_${pop}_beta_${pop}.txt \
#     --out ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_${pop}_beta_${pop}_prs_${pop2}
# fi
#
# done
#
# method=SDPRX
#
# if [[ ! -e ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_${pop2}_beta_EUR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_beta_EUR.txt \
#     --out ./result/score/diff_cohort/MIXPRS/${trait}_${method}_EUR_${pop2}_beta_EUR_prs_${pop2}
# fi
#
# done
# done

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# pop2=AFR
#
# ## JointPRS_meta
# method=JointPRS_meta
#
# if [[ ! -e ./result/score/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}
# fi
#
# done

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# pop2=AFR
#
# ## JointPRS_linear
# method=JointPRS_linear
#
# if [[ ! -e ./result/score/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_beta_${pop2}.txt header-read \
#     --score-col-nums 3 4 5 \
#     --out ./result/score/diff_cohort/JointPRS/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}
# fi
#
# done

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# pop2=AFR
#
# ## XPASS
# method=XPASS
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_prs_${pop2}
# fi
#
# done

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# pop2=AFR
#
# ## PRScsx
# method=PRScsx
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_beta_${pop2}.txt header-read \
#     --score-col-nums 3 4 5 \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}
# fi
#
# done

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# pop2=AFR
#
# ## MUSSEL
# method=MUSSEL
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}
# fi
#
# done

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# pop2=AFR
#
# ## PROSPER
# method=PROSPER
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_EAS_AFR_prs_${pop2}
# fi
#
# done

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# pop2=AFR
#
# ## PROSPER_update
# method=PROSPER
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_update_EUR_EAS_AFR_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_update_EUR_EAS_AFR_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_update_EUR_EAS_AFR_prs_${pop2}
# fi
#
# done

# %%
# %%bash
#
# for trait in Height BMI SBP DBP PLT; do
#
# pop2=AFR
#
# ## BridgePRS
# method=BridgePRS
#
# if [[ ! -e ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_prs_${pop2}.sscore ]]; then
# plink2 --bfile ./data/geno_data/${pop2} \
#     --extract ./data/snplist_data/${pop2}_inter_snplist_aou.txt \
#     --score ./data/final_weight/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_beta_${pop2}.txt \
#     --out ./result/score/diff_cohort/${method}/${trait}_${method}_EUR_${pop2}_prs_${pop2}
# fi
#
# done
